# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image, display
import random
import math
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import plot_model 
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, Activation,Concatenate
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import to_categorical 
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import backend, models
from sklearn.metrics import confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from tensorflow.keras.applications import VGG16, MobileNet
from keras.applications.vgg16 import preprocess_input

# %%
arabic_characters = ['alef', 'beh', 'teh', 'theh', 'jeem', 'hah', 'khah', 'dal', 'thal',
                    'reh', 'zain', 'seen', 'sheen', 'sad', 'dad', 'tah', 'zah', 'ain',
                    'ghain', 'feh', 'qaf', 'kaf', 'lam', 'meem', 'noon', 'heh', 'waw', 'yeh']

# %%
x_train = pd.read_csv("/content/csvTrainImages 13440x1024.csv",header=None).to_numpy()
y_train = pd.read_csv("/content/csvTrainLabel 13440x1.csv",header=None).to_numpy()-1 

x_test = pd.read_csv("/content/csvTestImages 3360x1024.csv",header=None).to_numpy()
y_test = pd.read_csv("/content/csvTestLabel 3360x1.csv",header=None).to_numpy()-1

print("x_train.shape =", x_train.shape, "\ny_train.shape =", y_train.shape, "\nx_test.shape =", x_test.shape, "\ny_test.shape =", y_test.shape)
# Out:
# x_train.shape = (13440, 1024)
# y_train.shape = (13440, 1)
# x_test.shape = (3360, 1024)
# y_test.shape = (3360, 1)

# %%
shape=(32,32,1)

# %%
x_train = x_train.reshape(-1,32,32,1)
x_test = x_test.reshape(-1,32,32,1)

x_train = x_train / 255.0
x_test = x_test / 255.0

print(x_train.shape, x_test.shape)

ra = np.random.randint(0, 13440, size=25)
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[ra[i]].reshape(32,32).T,"gray")
    plt.xlabel(arabic_characters[int(y_train[ra[i]][0])])
plt.show()
# Out:
# (13440, 32, 32, 1) (3360, 32, 32, 1)

# %%
from keras.utils.np_utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
print(y_train.shape, y_test.shape)
for i in zip(y_train[0], arabic_characters):
    print(i)
# Out:
# (13440, 28) (3360, 28)
# (1.0, 'alef')
# (0.0, 'beh')
# (0.0, 'teh')
# (0.0, 'theh')
# (0.0, 'jeem')
# (0.0, 'hah')
# (0.0, 'khah')
# (0.0, 'dal')
# (0.0, 'thal')
# (0.0, 'reh')
# (0.0, 'zain')
# (0.0, 'seen')
# (0.0, 'sheen')
# (0.0, 'sad')
# (0.0, 'dad')
# (0.0, 'tah')
# (0.0, 'zah')
# (0.0, 'ain')
# (0.0, 'ghain')
# (0.0, 'feh')
# (0.0, 'qaf')
# (0.0, 'kaf')
# (0.0, 'lam')
# (0.0, 'meem')
# (0.0, 'noon')
# (0.0, 'heh')
# (0.0, 'waw')
# (0.0, 'yeh')

# %%
len(y_test)
# Out:
# 3360

# %%
model = Sequential()

model.add(Conv2D(64, (3, 3), padding='same',input_shape=shape)) 
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3))) 
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) 
model.add(BatchNormalization())
model.add(Dropout(0.35))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization()) 

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) 
model.add(BatchNormalization())
model.add(Dropout(0.35)) #64 --> 42

model.add(Conv2D(64, (3, 3), padding='same')) 
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Flatten()) 
model.add(Dropout(0.5)) 
model.add(Dense(512)) 
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dense(28)) 
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 32, 32, 64)        640
# _________________________________________________________________
# activation_14 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 30, 30, 64)        36928
# _________________________________________________________________
# activation_15 (Activation)   (None, 30, 30, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 15, 15, 64)        0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 15, 15, 64)        256
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 15, 15, 64)        36928
# _________________________________________________________________
# activation_16 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 15, 15, 64)        256
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_17 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 6, 6, 64)          256
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 6, 6, 64)          36928
# _________________________________________________________________
# activation_18 (Activation)   (None, 6, 6, 64)          0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 6, 6, 64)          256
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 2304)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_19 (Activation)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_5 (Dense)              (None, 28)                14364
# _________________________________________________________________
# activation_20 (Activation)   (None, 28)                0
# =================================================================
# Total params: 1,346,204
# Trainable params: 1,344,540
# Non-trainable params: 1,664
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam',
               loss = 'categorical_crossentropy',
               metrics = ['accuracy'])

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  
        samplewise_center=False, 
        featurewise_std_normalization=False,  
        samplewise_std_normalization=False,  
        zca_whitening=False, 
        rotation_range=10,  
        zoom_range = 0.2,
        width_shift_range=0.2, 
        height_shift_range=0.2, 
        horizontal_flip=False,  
        vertical_flip=False) 
train_gen = datagen.flow(x_train, y_train, batch_size=batch_size)
test_gen = datagen.flow(x_test, y_test, batch_size=batch_size)

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("cnn.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)
# Out:
# 2021-10-31 18:20:53.465617: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2021-10-31 18:20:53.465940: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2021-10-31 18:20:53.703375: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2021-10-31 18:20:53.703583: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed

# %%
history = model.fit_generator(train_gen, epochs = 50, validation_data = test_gen, 
                            callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
#   1/210 [..............................] - ETA: 3:42 - loss: 4.3156 - accuracy: 0.0156
# 2021-10-31 18:21:22.345774: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2021-10-31 18:21:22.346370: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
#   2/210 [..............................] - ETA: 57s - loss: 4.1984 - accuracy: 0.0391
# 2021-10-31 18:21:22.581238: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2021-10-31 18:21:22.582242: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed
# 2021-10-31 18:21:22.713718: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:673]  GpuTracer has collected 252 callback api events and 249 activity events.
# 2021-10-31 18:21:22.722900: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2021-10-31 18:21:22.740111: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: logs/train/plugins/profile/2021_10_31_18_21_22
#
# 2021-10-31 18:21:22.745307: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to logs/train/plugins/profile/2021_10_31_18_21_22/f38e78ec9e46.trace.json.gz
# 2021-10-31 18:21:22.768066: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: logs/train/plugins/profile/2021_10_31_18_21_22
#
# 2021-10-31 18:21:22.770590: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to logs/train/plugins/profile/2021_10_31_18_21_22/f38e78ec9e46.memory_profile.json.gz
# 2021-10-31 18:21:22.771396: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: logs/train/plugins/profile/2021_10_31_18_21_22
# Dumped tool data for xplane.pb to logs/train/plugins/profile/2021_10_31_18_21_22/f38e78ec9e46.xplane.pb
# Dumped tool data for overview_page.pb to logs/train/plugins/profile/2021_10_31_18_21_22/f38e78ec9e46.overview_page.pb
# Dumped tool data for input_pipeline.pb to logs/train/plugins/profile/2021_10_31_18_21_22/f38e78ec9e46.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to logs/train/plugins/profile/2021_10_31_18_21_22/f38e78ec9e46.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to logs/train/plugins/profile/2021_10_31_18_21_22/f38e78ec9e46.kernel_stats.pb
# 210/210 [==============================] - 8s 33ms/step - loss: 2.5308 - accuracy: 0.2864 - val_loss: 7.8744 - val_accuracy: 0.0357
#
# Epoch 00001: val_accuracy improved from -inf to 0.03571, saving model to cnn.h5
# Epoch 2/50
# 210/210 [==============================] - 6s 30ms/step - loss: 1.1647 - accuracy: 0.6248 - val_loss: 5.1916 - val_accuracy: 0.1140
#
# Epoch 00002: val_accuracy improved from 0.03571 to 0.11399, saving model to cnn.h5
# Epoch 3/50
# 210/210 [==============================] - 6s 31ms/step - loss: 0.7608 - accuracy: 0.7508 - val_loss: 1.5486 - val_accuracy: 0.5420
#
# Epoch 00003: val_accuracy improved from 0.11399 to 0.54196, saving model to cnn.h5
# Epoch 4/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.5938 - accuracy: 0.8089 - val_loss: 0.5445 - val_accuracy: 0.8268
#
# Epoch 00004: val_accuracy improved from 0.54196 to 0.82679, saving model to cnn.h5
# Epoch 5/50
# 210/210 [==============================] - 7s 31ms/step - loss: 0.5138 - accuracy: 0.8355 - val_loss: 1.7230 - val_accuracy: 0.5625
#
# Epoch 00005: val_accuracy did not improve from 0.82679
# Epoch 6/50
# 210/210 [==============================] - 6s 30ms/step - loss: 0.4357 - accuracy: 0.8582 - val_loss: 1.1138 - val_accuracy: 0.6958
#
# Epoch 00006: val_accuracy did not improve from 0.82679
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 7/50
# 210/210 [==============================] - 7s 31ms/step - loss: 0.3557 - accuracy: 0.8827 - val_loss: 0.2855 - val_accuracy: 0.9125
#
# Epoch 00007: val_accuracy improved from 0.82679 to 0.91250, saving model to cnn.h5
# Epoch 8/50
# 210/210 [==============================] - 7s 34ms/step - loss: 0.3209 - accuracy: 0.8962 - val_loss: 0.2751 - val_accuracy: 0.9164
#
# Epoch 00008: val_accuracy improved from 0.91250 to 0.91637, saving model to cnn.h5
# Epoch 9/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.3126 - accuracy: 0.8995 - val_loss: 0.2137 - val_accuracy: 0.9339
#
# Epoch 00009: val_accuracy improved from 0.91637 to 0.93393, saving model to cnn.h5
# Epoch 10/50
# 210/210 [==============================] - 7s 32ms/step - loss: 0.2877 - accuracy: 0.9091 - val_loss: 1.2535 - val_accuracy: 0.6372
#
# Epoch 00010: val_accuracy did not improve from 0.93393
# Epoch 11/50
# 210/210 [==============================] - 6s 28ms/step - loss: 0.2899 - accuracy: 0.9088 - val_loss: 0.2183 - val_accuracy: 0.9315
#
# Epoch 00011: val_accuracy did not improve from 0.93393
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Epoch 12/50
# 210/210 [==============================] - 6s 30ms/step - loss: 0.2561 - accuracy: 0.9196 - val_loss: 0.2035 - val_accuracy: 0.9384
#
# Epoch 00012: val_accuracy improved from 0.93393 to 0.93839, saving model to cnn.h5
# Epoch 13/50
# 210/210 [==============================] - 7s 33ms/step - loss: 0.2544 - accuracy: 0.9202 - val_loss: 0.1812 - val_accuracy: 0.9429
#
# Epoch 00013: val_accuracy improved from 0.93839 to 0.94286, saving model to cnn.h5
# Epoch 14/50
# 210/210 [==============================] - 6s 28ms/step - loss: 0.2532 - accuracy: 0.9217 - val_loss: 0.1800 - val_accuracy: 0.9458
#
# Epoch 00014: val_accuracy improved from 0.94286 to 0.94583, saving model to cnn.h5
# Epoch 15/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2339 - accuracy: 0.9288 - val_loss: 0.1689 - val_accuracy: 0.9500
#
# Epoch 00015: val_accuracy improved from 0.94583 to 0.95000, saving model to cnn.h5
# Epoch 16/50
# 210/210 [==============================] - 6s 28ms/step - loss: 0.2360 - accuracy: 0.9281 - val_loss: 0.1673 - val_accuracy: 0.9491
#
# Epoch 00016: val_accuracy did not improve from 0.95000
# Epoch 17/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2293 - accuracy: 0.9286 - val_loss: 0.1770 - val_accuracy: 0.9467
#
# Epoch 00017: val_accuracy did not improve from 0.95000
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Epoch 18/50
# 210/210 [==============================] - 6s 31ms/step - loss: 0.2332 - accuracy: 0.9291 - val_loss: 0.1566 - val_accuracy: 0.9533
#
# Epoch 00018: val_accuracy improved from 0.95000 to 0.95327, saving model to cnn.h5
# Epoch 19/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2235 - accuracy: 0.9286 - val_loss: 0.1539 - val_accuracy: 0.9551
#
# Epoch 00019: val_accuracy improved from 0.95327 to 0.95506, saving model to cnn.h5
# Epoch 20/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2331 - accuracy: 0.9303 - val_loss: 0.1538 - val_accuracy: 0.9563
#
# Epoch 00020: val_accuracy improved from 0.95506 to 0.95625, saving model to cnn.h5
# Epoch 21/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2232 - accuracy: 0.9304 - val_loss: 0.1616 - val_accuracy: 0.9554
#
# Epoch 00021: val_accuracy did not improve from 0.95625
# Epoch 22/50
# 210/210 [==============================] - 6s 30ms/step - loss: 0.2185 - accuracy: 0.9314 - val_loss: 0.1684 - val_accuracy: 0.9491
#
# Epoch 00022: val_accuracy did not improve from 0.95625
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# Epoch 23/50
# 210/210 [==============================] - 7s 36ms/step - loss: 0.2192 - accuracy: 0.9310 - val_loss: 0.1446 - val_accuracy: 0.9539
#
# Epoch 00023: val_accuracy did not improve from 0.95625
# Epoch 24/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2200 - accuracy: 0.9315 - val_loss: 0.1511 - val_accuracy: 0.9554
#
# Epoch 00024: val_accuracy did not improve from 0.95625
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# Epoch 25/50
# 210/210 [==============================] - 6s 28ms/step - loss: 0.2092 - accuracy: 0.9339 - val_loss: 0.1537 - val_accuracy: 0.9536
#
# Epoch 00025: val_accuracy did not improve from 0.95625
# Epoch 26/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2187 - accuracy: 0.9319 - val_loss: 0.1474 - val_accuracy: 0.9557
#
# Epoch 00026: val_accuracy did not improve from 0.95625
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# Epoch 27/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2141 - accuracy: 0.9313 - val_loss: 0.1556 - val_accuracy: 0.9542
#
# Epoch 00027: val_accuracy did not improve from 0.95625
# Epoch 28/50
# 210/210 [==============================] - 6s 28ms/step - loss: 0.2135 - accuracy: 0.9333 - val_loss: 0.1592 - val_accuracy: 0.9530
#
# Epoch 00028: val_accuracy did not improve from 0.95625
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# Epoch 29/50
# 210/210 [==============================] - 7s 32ms/step - loss: 0.2129 - accuracy: 0.9348 - val_loss: 0.1487 - val_accuracy: 0.9551
#
# Epoch 00029: val_accuracy did not improve from 0.95625
# Epoch 30/50
# 210/210 [==============================] - 6s 28ms/step - loss: 0.2077 - accuracy: 0.9354 - val_loss: 0.1543 - val_accuracy: 0.9545
#
# Epoch 00030: val_accuracy did not improve from 0.95625
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
# Epoch 31/50
# 210/210 [==============================] - 6s 30ms/step - loss: 0.2190 - accuracy: 0.9334 - val_loss: 0.1568 - val_accuracy: 0.9539
#
# Epoch 00031: val_accuracy did not improve from 0.95625
# Epoch 32/50
# 210/210 [==============================] - 6s 28ms/step - loss: 0.2084 - accuracy: 0.9330 - val_loss: 0.1536 - val_accuracy: 0.9539
#
# Epoch 00032: val_accuracy did not improve from 0.95625
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
# Epoch 33/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2158 - accuracy: 0.9315 - val_loss: 0.1527 - val_accuracy: 0.9521
#
# Epoch 00033: val_accuracy did not improve from 0.95625
# Epoch 34/50
# 210/210 [==============================] - 7s 32ms/step - loss: 0.2163 - accuracy: 0.9352 - val_loss: 0.1590 - val_accuracy: 0.9557
#
# Epoch 00034: val_accuracy did not improve from 0.95625
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 5.904900035602622e-09.
# Epoch 35/50
# 210/210 [==============================] - 6s 28ms/step - loss: 0.2090 - accuracy: 0.9337 - val_loss: 0.1500 - val_accuracy: 0.9568
#
# Epoch 00035: val_accuracy improved from 0.95625 to 0.95685, saving model to cnn.h5
# Epoch 36/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2173 - accuracy: 0.9324 - val_loss: 0.1532 - val_accuracy: 0.9536
#
# Epoch 00036: val_accuracy did not improve from 0.95685
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.7714700373261393e-09.
# Epoch 37/50
# 210/210 [==============================] - 6s 27ms/step - loss: 0.2140 - accuracy: 0.9336 - val_loss: 0.1615 - val_accuracy: 0.9479
#
# Epoch 00037: val_accuracy did not improve from 0.95685
# Epoch 38/50
# 210/210 [==============================] - 6s 28ms/step - loss: 0.2085 - accuracy: 0.9343 - val_loss: 0.1530 - val_accuracy: 0.9539
#
# Epoch 00038: val_accuracy did not improve from 0.95685
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 5.314410245205181e-10.
# Epoch 39/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2188 - accuracy: 0.9313 - val_loss: 0.1525 - val_accuracy: 0.9539
#
# Epoch 00039: val_accuracy did not improve from 0.95685
# Epoch 40/50
# 210/210 [==============================] - 6s 27ms/step - loss: 0.2102 - accuracy: 0.9334 - val_loss: 0.1674 - val_accuracy: 0.9545
#
# Epoch 00040: val_accuracy did not improve from 0.95685
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.5943230069481729e-10.
# Epoch 41/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2170 - accuracy: 0.9337 - val_loss: 0.1448 - val_accuracy: 0.9536
#
# Epoch 00041: val_accuracy did not improve from 0.95685
# Epoch 42/50
# 210/210 [==============================] - 6s 27ms/step - loss: 0.2118 - accuracy: 0.9320 - val_loss: 0.1635 - val_accuracy: 0.9521
#
# Epoch 00042: val_accuracy did not improve from 0.95685
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 4.7829690208445185e-11.
# Epoch 43/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2134 - accuracy: 0.9350 - val_loss: 0.1623 - val_accuracy: 0.9506
#
# Epoch 00043: val_accuracy did not improve from 0.95685
# Epoch 44/50
# 210/210 [==============================] - 7s 31ms/step - loss: 0.2153 - accuracy: 0.9324 - val_loss: 0.1634 - val_accuracy: 0.9479
#
# Epoch 00044: val_accuracy did not improve from 0.95685
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.434890747886719e-11.
# Epoch 45/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2097 - accuracy: 0.9356 - val_loss: 0.1392 - val_accuracy: 0.9577
#
# Epoch 00045: val_accuracy improved from 0.95685 to 0.95774, saving model to cnn.h5
# Epoch 46/50
# 210/210 [==============================] - 6s 27ms/step - loss: 0.2234 - accuracy: 0.9288 - val_loss: 0.1471 - val_accuracy: 0.9542
#
# Epoch 00046: val_accuracy did not improve from 0.95774
# Epoch 47/50
# 210/210 [==============================] - 6s 30ms/step - loss: 0.2166 - accuracy: 0.9299 - val_loss: 0.1503 - val_accuracy: 0.9595
#
# Epoch 00047: val_accuracy improved from 0.95774 to 0.95952, saving model to cnn.h5
# Epoch 48/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2189 - accuracy: 0.9325 - val_loss: 0.1438 - val_accuracy: 0.9577
#
# Epoch 00048: val_accuracy did not improve from 0.95952
# Epoch 49/50
# 210/210 [==============================] - 6s 30ms/step - loss: 0.2133 - accuracy: 0.9325 - val_loss: 0.1550 - val_accuracy: 0.9533
#
# Epoch 00049: val_accuracy did not improve from 0.95952
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 4.304672243660157e-12.
# Epoch 50/50
# 210/210 [==============================] - 6s 29ms/step - loss: 0.2197 - accuracy: 0.9292 - val_loss: 0.1611 - val_accuracy: 0.9506
#
# Epoch 00050: val_accuracy did not improve from 0.95952

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot loss values vs epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
score = model.evaluate(x_test, y_test)
print('Test accuarcy: %0.2f%%' % (score[0] * 100))
# Out:
# 105/105 [==============================] - 0s 3ms/step - loss: 0.0935 - accuracy: 0.9768
# Test accuarcy: 9.35%

# %%
plt.imshow(x_test[20])
plt.show()

# %%
pred = model.predict(x_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       120
#            1       0.99      0.99      0.99       120
#            2       0.94      0.98      0.96       120
#            3       0.99      0.97      0.98       120
#            4       0.98      1.00      0.99       120
#            5       0.99      0.98      0.99       120
#            6       0.99      0.99      0.99       120
#            7       0.97      0.96      0.97       120
#            8       0.95      0.93      0.94       120
#            9       0.95      0.99      0.97       120
#           10       0.96      0.92      0.94       120
#           11       1.00      0.97      0.99       120
#           12       0.98      1.00      0.99       120
#           13       0.94      1.00      0.97       120
#           14       0.98      0.97      0.97       120
#           15       0.96      0.96      0.96       120
#           16       0.96      0.96      0.96       120
#           17       0.98      0.97      0.98       120
#           18       0.98      1.00      0.99       120
#           19       0.97      0.97      0.97       120
#           20       0.98      0.97      0.97       120
#           21       0.98      0.99      0.98       120
#           22       0.98      0.99      0.99       120
#           23       0.99      0.99      0.99       120
#           24       0.98      0.94      0.96       120
#           25       0.98      0.99      0.98       120
#           26       0.98      0.96      0.97       120
#           27       1.00      1.00      1.00       120
#
#     accuracy                           0.98      3360
#    macro avg       0.98      0.98      0.98      3360
# weighted avg       0.98      0.98      0.98      3360

# %%
from sklearn.metrics import confusion_matrix

fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=arabic_characters,yticklabels=arabic_characters,annot=True)


plt.show()
